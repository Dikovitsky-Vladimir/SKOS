# %%
import torch 
print (torch.cuda.is_available())
# Out:
# False

# %% [markdown]
# Installing Packages

# %%
#!pip install -r /content/requirements.txt
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: sentencepiece==0.1.95 in c:\python\python36\lib\site-packages (from -r requirements.txt (line 2)) (0.1.95)
# Requirement already satisfied: transformers==4.5.1 in c:\python\python36\lib\site-packages (from -r requirements.txt (line 3)) (4.5.1)
# Requirement already satisfied: pandas==1.1.5 in c:\python\python36\lib\site-packages (from -r requirements.txt (line 4)) (1.1.5)
# Requirement already satisfied: numpy==1.19.5 in c:\python\python36\lib\site-packages (from -r requirements.txt (line 5)) (1.19.5)
# Requirement already satisfied: scikit-learn==0.22.2 in c:\python\python36\lib\site-packages (from -r requirements.txt (line 6)) (0.22.2)
# Requirement already satisfied: pytz>=2017.2 in c:\python\python36\lib\site-packages (from pandas==1.1.5->-r requirements.txt (line 4)) (2020.4)
# Requirement already satisfied: numpy==1.19.5 in c:\python\python36\lib\site-packages (from -r requirements.txt (line 5)) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\python\python36\lib\site-packages (from pandas==1.1.5->-r requirements.txt (line 4)) (2.8.1)
# Requirement already satisfied: scipy>=0.17.0 in c:\python\python36\lib\site-packages (from scikit-learn==0.22.2->-r requirements.txt (line 6)) (1.4.1)
# Requirement already satisfied: numpy==1.19.5 in c:\python\python36\lib\site-packages (from -r requirements.txt (line 5)) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in c:\python\python36\lib\site-packages (from scikit-learn==0.22.2->-r requirements.txt (line 6)) (1.0.0)
# Collecting torch==1.8.1
#   Using cached torch-1.8.1-cp36-cp36m-win_amd64.whl (190.5 MB)
# Requirement already satisfied: typing-extensions in c:\python\python36\lib\site-packages (from torch==1.8.1->-r requirements.txt (line 1)) (3.7.4.3)
# Requirement already satisfied: numpy==1.19.5 in c:\python\python36\lib\site-packages (from -r requirements.txt (line 5)) (1.19.5)
# Requirement already satisfied: dataclasses in c:\users\dikov\appdata\roaming\python\python36\site-packages (from torch==1.8.1->-r requirements.txt (line 1)) (0.8)
# Requirement already satisfied: regex!=2019.12.17 in c:\python\python36\lib\site-packages (from transformers==4.5.1->-r requirements.txt (line 3)) (2020.11.13)
# Requirement already satisfied: sacremoses in c:\python\python36\lib\site-packages (from transformers==4.5.1->-r requirements.txt (line 3)) (0.0.43)
# Requirement already satisfied: numpy==1.19.5 in c:\python\python36\lib\site-packages (from -r requirements.txt (line 5)) (1.19.5)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\python\python36\lib\site-packages (from transformers==4.5.1->-r requirements.txt (line 3)) (0.10.1)
# Requirement already satisfied: filelock in c:\python\python36\lib\site-packages (from transformers==4.5.1->-r requirements.txt (line 3)) (3.0.12)
# Requirement already satisfied: tqdm>=4.27 in c:\python\python36\lib\site-packages (from transformers==4.5.1->-r requirements.txt (line 3)) (4.54.1)
# Requirement already satisfied: importlib-metadata in c:\python\python36\lib\site-packages (from transformers==4.5.1->-r requirements.txt (line 3)) (3.10.1)
# Requirement already satisfied: requests in c:\python\python36\lib\site-packages (from transformers==4.5.1->-r requirements.txt (line 3)) (2.25.1)
# Requirement already satisfied: packaging in c:\python\python36\lib\site-packages (from transformers==4.5.1->-r requirements.txt (line 3)) (20.8)
# Requirement already satisfied: dataclasses in c:\users\dikov\appdata\roaming\python\python36\site-packages (from torch==1.8.1->-r requirements.txt (line 1)) (0.8)
# Requirement already satisfied: zipp>=0.5 in c:\python\python36\lib\site-packages (from importlib-metadata->transformers==4.5.1->-r requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: typing-extensions in c:\python\python36\lib\site-packages (from torch==1.8.1->-r requirements.txt (line 1)) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\python\python36\lib\site-packages (from packaging->transformers==4.5.1->-r requirements.txt (line 3)) (2.4.7)
# Requirement already satisfied: six>=1.5 in c:\python\python36\lib\site-packages (from python-dateutil>=2.7.3->pandas==1.1.5->-r requirements.txt (line 4)) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\python36\lib\site-packages (from requests->transformers==4.5.1->-r requirements.txt (line 3)) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\python\python36\lib\site-packages (from requests->transformers==4.5.1->-r requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\python\python36\lib\site-packages (from requests->transformers==4.5.1->-r requirements.txt (line 3)) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python\python36\lib\site-packages (from requests->transformers==4.5.1->-r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\python\python36\lib\site-packages (from transformers==4.5.1->-r requirements.txt (line 3)) (2020.11.13)
# Requirement already satisfied: joblib>=0.11 in c:\python\python36\lib\site-packages (from scikit-learn==0.22.2->-r requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: six>=1.5 in c:\python\python36\lib\site-packages (from python-dateutil>=2.7.3->pandas==1.1.5->-r requirements.txt (line 4)) (1.15.0)
# Requirement already satisfied: click in c:\python\python36\lib\site-packages (from sacremoses->transformers==4.5.1->-r requirements.txt (line 3)) (7.1.2)
# Requirement already satisfied: tqdm>=4.27 in c:\python\python36\lib\site-packages (from transformers==4.5.1->-r requirements.txt (line 3)) (4.54.1)
# Requirement already satisfied: numpy==1.19.5 in c:\python\python36\lib\site-packages (from -r requirements.txt (line 5)) (1.19.5)
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.1
#     Uninstalling torch-1.10.1:
#       Successfully uninstalled torch-1.10.1
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Отказано в доступе: 'c:\\python\\python36\\lib\\site-packages\\~-rch\\lib\\asmjit.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 20.3.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\python\python36\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
train_data = pd.read_csv('train.csv')
valid_data = pd.read_csv('valid.csv')
test_data  = pd.read_csv('test.csv')
#train_data = pd.read_csv('db10-1.csv') # broader + not broader

# %%
from bert_dataset import CustomDataset
from bert_classifier import BertClassifier

# %%
import torch

if torch.cuda.is_available():       
    device = torch.device("cuda")
    print(f'There are {torch.cuda.device_count()} GPU(s) available.')
    print('Device name:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# No GPU available, using the CPU instead.

# %%
from bert_classifier import BertClassifier
model = BertClassifier(data_processor, 
                       num_labels, 
                       bert_config_file,
                       max_seq_length, 
                       vocab_file, 
                       tensorboard_dir, 
                       init_checkpoint, 
                       keep_checkpoint_max, 
                       use_GPU, 
                       label_smoothing, 
                       cycle)
#model.predict(file_path='./data/test.tsv', predict_batch_size=128, output_dir='./predict')
# Or single sample inference
# prob = model.predict(input_example=input_example)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-9ee02526f42c> in <module>
#       1 from bert_classifier import BertClassifier
# ----> 2 model = BertClassifier(data_processor,
#       3                        num_labels,
#       4                        bert_config_file,
#       5                        max_seq_length,
#
# NameError: name 'data_processor' is not defined

# %% [markdown]
# Initialize BERT classifier

# %%
classifier = BertClassifier(
        model_path='cointegrated/rubert-tiny',
        tokenizer_path='cointegrated/rubert-tiny',
        n_classes=2,
        epochs=2,
        model_save_path='bert.pt',
        
)
# Out:
# Some weights of the model checkpoint at cointegrated/rubert-tiny were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at cointegrated/rubert-tiny and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# Prepare data and helpers for train and evlauation

# %%
classifier.preparation(
        X_train=list(train_data['text']),
        y_train=list(train_data['label']),
        X_valid=list(valid_data['text']),
        y_valid=list(valid_data['label'])
    )

# %% [markdown]
# Train loop

# %%
classifier.train()
# Out:
# Epoch 1/2
# Train loss 0.42354585234160597 accuracy 0.8873295910184442
# Val loss 0.4121066030478353 accuracy 0.8997912317327766
# ----------
# Epoch 2/2
# Train loss 0.30102264597629586 accuracy 0.9296311146752205
# Val loss 0.37973104637844823 accuracy 0.918580375782881
# ----------

# %% [markdown]
# Check test data

# %%
texts = list(test_data['text'])
labels = list(test_data['label'])

predictions = [classifier.predict(t) for t in texts]

# %%
from sklearn.metrics import precision_recall_fscore_support

precision, recall, f1score = precision_recall_fscore_support(labels, predictions,average='macro')[:3]

print(f'precision: {precision}, recall: {recall}, f1score: {f1score}')
# Out:
# precision: 0.933658620099298, recall: 0.9333239560840607, f1score: 0.9327454074425223
